# %%
from src.ner.inference import load_model, predict

# %%
model, tokenizer = load_model()
# Out:
# Loading weights: 100%|██████████| 102/102 [00:00<00:00, 12448.18it/s]

# %%
text = input("Введіть речення: ")

# %%
predict(model, tokenizer, text)
# Out:
# ['cows']
