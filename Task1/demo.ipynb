# %% [markdown]
# # MNIST Classification Demo
#
# This notebook demonstrates how the implemented classifiers work on the MNIST dataset.
#
# Implemented models:
# - Random Forest
# - Feed-Forward Neural Network
# - Convolutional Neural Network
#
# The demo shows:
# - loading the dataset
# - training models
# - making predictions
# - evaluation
# - edge cases

# %%
from data.mnist_loader import load_mnist
from utils.visualization import show_misclassified_examples
from classifier import mnist_classifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Load MNIST dataset

# %%
X_train, X_test, y_train, y_test = load_mnist()

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (56000, 784)
# Test shape: (14000, 784)

# %% [markdown]
# ### Example images from dataset

# %%
fig, axes = plt.subplots(1,5, figsize=(10,3))

for i in range(5):
    axes[i].imshow(X_train[i].reshape(28,28), cmap="gray")
    axes[i].set_title(y_train[i])
    axes[i].axis("off")

plt.show()

# %% [markdown]
# <center>
#
# ## Random Forest
#
# </center>

# %% [markdown]
# #### Train model

# %%
rf_model = mnist_classifier.MnistClassifier("rf")

rf_model.train(X_train, y_train)
# Out:
# Training Random Forest...
# Random Forest training finished

# %% [markdown]
# #### Predictions

# %%
rf_pred = rf_model.predict(X_test)

print("First 10 predictions:")
for i in range(10):
    print(f"Prediction: {rf_pred[i]}, True label: {y_test[i]}")
# Out:
# First 10 predictions:
# Prediction: 0, True label: 0
# Prediction: 0, True label: 0
# Prediction: 4, True label: 4
# Prediction: 6, True label: 6
# Prediction: 1, True label: 1
# Prediction: 8, True label: 8
# Prediction: 9, True label: 9
# Prediction: 7, True label: 7
# Prediction: 5, True label: 5
# Prediction: 6, True label: 6

# %% [markdown]
# #### Evaluation

# %%
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1381
#            1       0.98      0.99      0.99      1575
#            2       0.95      0.98      0.96      1398
#            3       0.97      0.96      0.97      1428
#            4       0.97      0.97      0.97      1365
#            5       0.98      0.97      0.97      1263
#            6       0.98      0.99      0.98      1375
#            7       0.98      0.97      0.97      1459
#            8       0.96      0.96      0.96      1365
#            9       0.95      0.95      0.95      1391
#
#     accuracy                           0.97     14000
#    macro avg       0.97      0.97      0.97     14000
# weighted avg       0.97      0.97      0.97     14000

# %% [markdown]
# #### Confusion matrix

# %%
cm = confusion_matrix(y_test, rf_pred)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Random Forest Confusion Matrix")
plt.show()

# %% [markdown]
# #### Misclassified examples

# %%
show_misclassified_examples(X_test, y_test, rf_pred)

# %% [markdown]
# <center>
#
# ## Feed-Forward Neural Network
#
# </center>

# %% [markdown]
# #### Train model

# %%
nn_model = mnist_classifier.MnistClassifier("nn")

nn_model.train(X_train, y_train)
# Out:
# NN Epoch 1/50: 100%|██████████| 875/875 [00:00<00:00, 877.35it/s]
# loss: 314.0440
# NN Epoch 2/50: 100%|██████████| 875/875 [00:00<00:00, 961.31it/s]
# loss: 136.6945
# NN Epoch 3/50: 100%|██████████| 875/875 [00:00<00:00, 937.90it/s]
# loss: 92.0827
# NN Epoch 4/50: 100%|██████████| 875/875 [00:00<00:00, 1046.82it/s]
# loss: 66.7571
# NN Epoch 5/50: 100%|██████████| 875/875 [00:00<00:00, 1013.92it/s]
# loss: 51.9798
# NN Epoch 6/50: 100%|██████████| 875/875 [00:00<00:00, 1029.46it/s]
# loss: 41.6351
# NN Epoch 7/50: 100%|██████████| 875/875 [00:00<00:00, 1073.11it/s]
# loss: 34.2757
# NN Epoch 8/50: 100%|██████████| 875/875 [00:00<00:00, 1088.42it/s]
# loss: 26.8543
# NN Epoch 9/50: 100%|██████████| 875/875 [00:00<00:00, 1068.17it/s]
# loss: 21.6696
# NN Epoch 10/50: 100%|██████████| 875/875 [00:00<00:00, 886.05it/s]
# loss: 17.9388
# NN Epoch 11/50: 100%|██████████| 875/875 [00:01<00:00, 835.67it/s]
# loss: 17.1943
# ...

# %% [markdown]
# #### Predictions

# %%
nn_pred = nn_model.predict(X_test)

print("First 10 predictions:")
for i in range(10):
    print(f"Prediction: {nn_pred[i]}, True label: {y_test[i]}")
# Out:
# First 10 predictions:
# Prediction: 0, True label: 0
# Prediction: 0, True label: 0
# Prediction: 4, True label: 4
# Prediction: 6, True label: 6
# Prediction: 1, True label: 1
# Prediction: 3, True label: 8
# Prediction: 9, True label: 9
# Prediction: 7, True label: 7
# Prediction: 5, True label: 5
# Prediction: 6, True label: 6

# %% [markdown]
# #### Evaluation

# %%
print(classification_report(y_test, nn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1381
#            1       0.99      0.99      0.99      1575
#            2       0.98      0.96      0.97      1398
#            3       0.98      0.98      0.98      1428
#            4       0.97      0.99      0.98      1365
#            5       0.97      0.98      0.97      1263
#            6       0.98      0.98      0.98      1375
#            7       0.97      0.97      0.97      1459
#            8       0.97      0.96      0.97      1365
#            9       0.97      0.97      0.97      1391
#
#     accuracy                           0.98     14000
#    macro avg       0.98      0.98      0.98     14000
# weighted avg       0.98      0.98      0.98     14000

# %% [markdown]
# #### Confusion matrix

# %%
cm = confusion_matrix(y_test, nn_pred)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Neural Network Confusion Matrix")
plt.show()

# %% [markdown]
# #### Misclassified examples

# %%
show_misclassified_examples(X_test, y_test, nn_pred)

# %% [markdown]
# <center>
#
# ## Convolutional Neural Network
#
# </center>

# %% [markdown]
# #### Train model

# %%
cnn_model = mnist_classifier.MnistClassifier("cnn")

cnn_model.train(X_train, y_train)
# Out:
# CNN Epoch 1/10: 100%|██████████| 875/875 [00:18<00:00, 47.15it/s]
# loss: 172.3494
# CNN Epoch 2/10: 100%|██████████| 875/875 [00:17<00:00, 49.57it/s]
# loss: 46.9107
# CNN Epoch 3/10: 100%|██████████| 875/875 [00:17<00:00, 48.84it/s]
# loss: 32.1591
# CNN Epoch 4/10: 100%|██████████| 875/875 [00:18<00:00, 48.43it/s]
# loss: 23.7923
# CNN Epoch 5/10: 100%|██████████| 875/875 [00:17<00:00, 48.88it/s]
# loss: 19.2336
# CNN Epoch 6/10: 100%|██████████| 875/875 [00:18<00:00, 48.30it/s]
# loss: 14.7334
# CNN Epoch 7/10: 100%|██████████| 875/875 [00:18<00:00, 48.58it/s]
# loss: 11.7777
# CNN Epoch 8/10: 100%|██████████| 875/875 [00:18<00:00, 48.07it/s]
# loss: 9.0701
# CNN Epoch 9/10: 100%|██████████| 875/875 [00:18<00:00, 47.97it/s]
# loss: 8.5099
# CNN Epoch 10/10: 100%|██████████| 875/875 [00:17<00:00, 48.80it/s]
# loss: 7.3427

# %% [markdown]
# #### Predictions

# %%
cnn_pred = cnn_model.predict(X_test)

print("First 10 predictions:")
for i in range(10):
    print(f"Prediction: {cnn_pred[i]}, True label: {y_test[i]}")
# Out:
# First 10 predictions:
# Prediction: 0, True label: 0
# Prediction: 0, True label: 0
# Prediction: 4, True label: 4
# Prediction: 6, True label: 6
# Prediction: 1, True label: 1
# Prediction: 8, True label: 8
# Prediction: 9, True label: 9
# Prediction: 7, True label: 7
# Prediction: 5, True label: 5
# Prediction: 6, True label: 6

# %% [markdown]
# #### Evaluation

# %%
print(classification_report(y_test, cnn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1381
#            1       0.99      0.99      0.99      1575
#            2       0.99      0.99      0.99      1398
#            3       0.99      0.99      0.99      1428
#            4       0.99      0.99      0.99      1365
#            5       0.99      0.99      0.99      1263
#            6       0.99      0.99      0.99      1375
#            7       0.99      0.99      0.99      1459
#            8       0.99      0.99      0.99      1365
#            9       0.99      0.98      0.98      1391
#
#     accuracy                           0.99     14000
#    macro avg       0.99      0.99      0.99     14000
# weighted avg       0.99      0.99      0.99     14000

# %% [markdown]
# #### Confusion matrix

# %%
cm = confusion_matrix(y_test, cnn_pred)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Convolutional Neural Network Confusion Matrix")
plt.show()

# %% [markdown]
# #### Misclassified examples

# %%
show_misclassified_examples(X_test, y_test, cnn_pred)

# %% [markdown]
# # Edge cases

# %% [markdown]
# #### Single image prediction
# Check that the model can make a prediction for a single image, not only for a full dataset.

# %%
pred = cnn_model.predict(X_test[0].reshape(1,-1))

print(f"Prediction: {pred[0]}")
print(f"True label: {y_test[0]}")
# Out:
# Prediction: 0
# True label: 0

# %% [markdown]
# #### Random noise
# Test how the model behaves when the input is random noise instead of a real digit.

# %%
noise = np.random.rand(1,784)

pred = cnn_model.predict(noise)

plt.imshow(noise.reshape(28,28), cmap="gray")
plt.title(f"Prediction for noise: {pred[0]}")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %% [markdown]
# #### Invalid input
# Check how the model handles invalid or empty input.

# %%
try:
    cnn_model.predict([])
except Exception as e:
    print(e)

# %% [markdown]
# #### Prediction shape
# Verify that the prediction output has the expected shape.

# %%
cnn_model.predict(X_test[:5]).shape
# Out:
# (5,)
